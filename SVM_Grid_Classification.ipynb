# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
indep=dataset[['User ID', 'Age', 'EstimatedSalary','Gender_Male']]
dep=dataset[['Purchased']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(indep,dep,test_size=1/3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.svm import SVC

# %%
from sklearn.model_selection import GridSearchCV

param_grid={'kernel':['linear','rbf','sigmoid','poly'],
           'gamma':['auto','scale'],
           'C':[10,100,1000,2000,3000]}

grid=GridSearchCV(SVC(probability=True),param_grid,refit=True,verbose=3,n_jobs=-1,scoring='f1_weighted')

#fiting the model for grid search
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# C:\Users\ELCOT\Anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['linear', 'rbf', 'sigmoid', 'poly']},
#              scoring='f1_weighted', verbose=3)

# %%
#print the best parameter aftertunning
#print (grid.best_params_)
re=grid.cv_results_
grid_prediction=grid.predict(x_test)

from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,grid_prediction)

#print classification Report
from sklearn.metrics import classification_report
clf_report=classification_report(y_test,grid_prediction)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_prediction,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}: 0.9104477611940298

# %%
print("The confusion matrix:\n",cm)
print("The report:\n",clf_report)
# Out:
# The confusion matrix:
#  [[79  6]
#  [ 6 43]]
# The report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93        85
#            1       0.88      0.88      0.88        49
#
#     accuracy                           0.91       134
#    macro avg       0.90      0.90      0.90       134
# weighted avg       0.91      0.91      0.91       134

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,grid.predict_proba(x_test)[:,1])
# Out:
# 0.9584633853541417

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.047999      0.007484         0.008001        0.007485      10
# 1        0.045999      0.010197         0.006001        0.004900      10
# 2        0.033996      0.008000         0.008003        0.007484      10
# 3        0.040006      0.010953         0.005995        0.004895      10
# 4        0.049998      0.008946         0.008003        0.007486      10
# 5        0.034002      0.010199         0.005998        0.004897      10
# 6        0.035997      0.004903         0.002000        0.004000      10
# 7        0.047998      0.007485         0.006002        0.008004      10
# 8        0.228002      0.039191         0.002001        0.004002     100
# 9        0.046000      0.012001         0.006002        0.004900     100
# 10       0.030000      0.008942         0.005999        0.004898     100
# 11       0.194001      0.071725         0.006001        0.004900     100
# 12       0.214004      0.063113         0.005995        0.004895     100
# 13       0.045997      0.016253         0.006003        0.004901     100
# 14       0.032005      0.007484         0.007997        0.007483     100
# 15       0.193998      0.061516         0.002001        0.004002     100
# 16       1.538017      0.458015         0.002002        0.004005    1000
# 17       0.072001      0.011664         0.004000        0.004899    1000
# 18       0.028002      0.011666         0.006000        0.004899    1000
# 19       1.236016      0.198962         0.002001        0.004002    1000
# 20       1.204013      0.310786         0.001999        0.003998    1000
# 21       0.073999      0.018547         0.006001        0.008001    1000
# 22       0.032000      0.017206         0.006001        0.008001    1000
# 23       1.324016      0.380457         0.002000        0.004001    1000
# 24       2.744034      0.744903         0.003999        0.004898    2000
# 25       0.057997      0.017204         0.002001        0.004002    2000
# 26       0.022001      0.003999         0.007999        0.007483    2000
# 27       3.198041      0.983117         0.002000        0.004000    2000
# 28       2.964037      0.654459         0.004002        0.004901    2000
# 29       0.073999      0.020591         0.002000        0.004000    2000
# 30       0.025998      0.004897         0.002000        0.004000    2000
# 31       2.154022      0.363739         0.002001        0.004001    2000
# 32       4.010051      1.240291         0.004000        0.004899    3000
# 33       0.080000      0.010954         0.002000        0.004001    3000
# 34       0.024001      0.007998         0.011999        0.007483    3000
# 35       3.922050      0.223018         0.002001        0.004002    3000
# 36       3.548045      0.742744         0.004000        0.004899    3000
# 37       0.074000      0.014966         0.005998        0.004898    3000
# 38       0.032000      0.003999         0.007999        0.007483    3000
# 39       2.763657      0.940685         0.006002        0.004900    3000
#
#    param_gamma param_kernel  \
# 0         auto       linear
# 1         auto          rbf
# 2         auto      sigmoid
# 3         auto         poly
# 4        scale       linear
# 5        scale          rbf
# 6        scale      sigmoid
# 7        scale         poly
# 8         auto       linear
# 9         auto          rbf
# 10        auto      sigmoid
# 11        auto         poly
# 12       scale       linear
# 13       scale          rbf
# 14       scale      sigmoid
# 15       scale         poly
# 16        auto       linear
# 17        auto          rbf
# 18        auto      sigmoid
# 19        auto         poly
# 20       scale       linear
# 21       scale          rbf
# 22       scale      sigmoid
# 23       scale         poly
# 24        auto       linear
# 25        auto          rbf
# 26        auto      sigmoid
# 27        auto         poly
# 28       scale       linear
# 29       scale          rbf
# 30       scale      sigmoid
# 31       scale         poly
# 32        auto       linear
# 33        auto          rbf
# 34        auto      sigmoid
# 35        auto         poly
# 36       scale       linear
# 37       scale          rbf
# 38       scale      sigmoid
# 39       scale         poly
#
#                                                params  split0_test_score  \
# 0      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.822092
# 1         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}           0.887346
# 2     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.749046
# 3        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.799620
# 4     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.822092
# 5        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}           0.887346
# 6    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.749046
# 7       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.799620
# 8     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.822092
# 9        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.847141
# 10   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.753889
# 11      {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.804764
# 12   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.822092
# 13      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.847141
# 14  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.753889
# 15     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.804764
# 16   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.822092
# 17      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.791752
# 18  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.753889
# 19     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.804764
# 20  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.822092
# 21     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.791752
# 22  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.777778
# 23    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.804764
# 24   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.822092
# 25      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.791752
# 26  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.777778
# 27     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.804764
# 28  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.822092
# 29     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.791752
# 30  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...           0.777778
# 31    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.804764
# 32   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.822092
# 33      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.791752
# 34  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.753889
# 35     {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}           0.804764
# 36  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.822092
# 37     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           0.791752
# 38  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...           0.777778
# 39    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}           0.804764
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.787284           0.721794           0.905069
# 1            0.849057           0.832483           0.886792
# 2            0.701618           0.672275           0.740593
# 3            0.765553           0.805463           0.818941
# 4            0.787284           0.721794           0.905069
# 5            0.849057           0.832483           0.886792
# 6            0.701618           0.672275           0.759493
# 7            0.765553           0.805463           0.818941
# 8            0.787284           0.721794           0.905069
# 9            0.831253           0.832483           0.886792
# 10           0.701618           0.587326           0.741078
# 11           0.765553           0.787943           0.801281
# 12           0.787284           0.721794           0.905069
# 13           0.831253           0.832483           0.886792
# 14           0.718755           0.587326           0.741078
# 15           0.765553           0.787943           0.801281
# 16           0.787284           0.721794           0.905069
# 17           0.831253           0.833323           0.775815
# 18           0.684401           0.643430           0.778179
# 19           0.770070           0.787943           0.801281
# 20           0.787284           0.721794           0.905069
# 21           0.831253           0.833323           0.775815
# 22           0.718755           0.643430           0.739245
# 23           0.770070           0.787943           0.801281
# 24           0.787284           0.721794           0.905069
# 25           0.811321           0.833323           0.775815
# 26           0.758660           0.643430           0.778179
# 27           0.770070           0.787943           0.801281
# 28           0.787284           0.721794           0.905069
# 29           0.811321           0.833323           0.775815
# 30           0.758660           0.633719           0.740593
# 31           0.770070           0.787943           0.801281
# 32           0.787284           0.721794           0.905069
# 33           0.811321           0.833323           0.775815
# 34           0.758660           0.643430           0.778179
# 35           0.770070           0.787943           0.801281
# 36           0.787284           0.721794           0.905069
# 37           0.811321           0.833323           0.795256
# 38           0.758660           0.633719           0.740593
# 39           0.770070           0.787943           0.801281
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.865054         0.820259        0.063223                5
# 1            0.885265         0.868188        0.023003                1
# 2            0.735849         0.719876        0.028756               36
# 3            0.841025         0.806120        0.024783               30
# 4            0.865054         0.820259        0.063223                5
# 5            0.885265         0.868188        0.023003                1
# 6            0.715207         0.719528        0.031752               37
# 7            0.862442         0.810404        0.031411               21
# 8            0.865054         0.820259        0.063223                5
# 9            0.883278         0.856189        0.024232                3
# 10           0.715207         0.699824        0.059196               40
# 11           0.883278         0.808564        0.039812               28
# 12           0.865054         0.820259        0.063223                5
# 13           0.883278         0.856189        0.024232                3
# 14           0.732285         0.706666        0.060760               39
# 15           0.883278         0.808564        0.039812               28
# 16           0.865054         0.820259        0.063223                5
# 17           0.847020         0.815832        0.027194               15
# 18           0.735849         0.719150        0.048808               38
# 19           0.883278         0.809467        0.038865               22
# 20           0.865054         0.820259        0.063223                5
# 21           0.847020         0.815832        0.027194               15
# 22           0.735849         0.723011        0.044224               35
# 23           0.883278         0.809467        0.038865               22
# 24           0.865054         0.820259        0.063223                5
# 25           0.847020         0.811846        0.026080               18
# 26           0.735849         0.738779        0.050137               31
# 27           0.883278         0.809467        0.038865               22
# 28           0.865054         0.820259        0.063223                5
# 29           0.847020         0.811846        0.026080               18
# 30           0.735849         0.729320        0.050036               33
# 31           0.883278         0.809467        0.038865               22
# 32           0.865054         0.820259        0.063223                5
# 33           0.847020         0.811846        0.026080               18
# 34           0.735849         0.734001        0.047248               32
# 35           0.883278         0.809467        0.038865               22
# 36           0.865054         0.820259        0.063223                5
# 37           0.847020         0.815734        0.021458               17
# 38           0.735849         0.729320        0.050036               33
# 39           0.883278         0.809467        0.038865               22

# %%
age_input=int(input("enter age:"))
salary_input=float(input("enter salary:"))
sex_male_input=int(input("enter sex male 0 or 1:"))
id_input=int(input("enter_id"))
# Out:
# enter age:33
# enter salary:40000
# enter sex male 0 or 1:0
# enter_id2345

# %%
Future_prediction=grid.predict([[age_input,salary_input,sex_male_input,id_input]])
print("Future_prediction={}".format(Future_prediction))
# Out:
# Future_prediction=[1]
